# %%
import pandas as pd

# %%
df=pd.read_csv('cricket test match.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4   H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  60.73  6558+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
df.head()
# Out:
#               Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0   DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1     AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2    RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3    GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4  H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  60.73  6558+
#
#       SR  100  50  0    4s  6s
# 0  58.60   29  13  7  626+   6
# 1  55.68    5   4  2   186   5
# 2  54.48    7  11  1  246+  11
# 3  56.00   10   5  2  104+   1
# 4  34.59   16  23  2  202+   6

# %%
df.describe()
# Out:
#               Mat        Inns         NO          Runs        Ave         SR  \
# count   65.000000   65.000000  65.000000     65.000000  65.000000  64.000000
# mean    77.938462  132.200000  13.815385   6280.230769  53.769231  47.656719
# std     50.908888   86.653801  11.181587   4030.044381   6.996523  15.423631
# min     14.000000   20.000000   1.000000    990.000000  48.000000   0.000000
# 25%     23.000000   41.000000   5.000000   2190.000000  49.560000  42.487500
# 50%     79.000000  131.000000  12.000000   6149.000000  52.050000  48.900000
# 75%    117.000000  195.000000  19.000000   8832.000000  56.680000  54.802500
# max    200.000000  329.000000  49.000000  15921.000000  99.940000  87.730000
#
#              100         50          0
# count  65.000000  65.000000  65.000000
# mean   18.861538  28.030769   7.569231
# std    12.409519  18.686534   5.502753
# min     1.000000   3.000000   1.000000
# 25%     7.000000  10.000000   3.000000
# ...

# %%
df.columns.tolist()
# Out:
# ['Player',
#  'Span',
#  'Mat',
#  'Inns',
#  'NO',
#  'Runs',
#  'HS',
#  'Ave',
#  'BF',
#  'SR',
#  '100',
#  '50',
#  '0',
#  '4s',
#  '6s']

# %%
df=df.rename(columns={'Mat':'Matches','NO':'Not_Outs','HS':'Highest_Inns_Score','BF':'Balls_Faced','SR':'Batting_Strike_Rate'})

# %%
df.head()
# Out:
#               Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0   DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1     AC Voges (AUS)  2015-2016       20    31         7  1485
# 2    RG Pollock (SA)  1963-1970       23    41         4  2256
# 3    GA Headley (WI)  1930-1954       22    40         4  2190
# 4  H Sutcliffe (ENG)  1924-1935       54    84         9  4555
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 0                334  99.94       9800+                58.60   29  13  7
# 1               269*  61.87        2667                55.68    5   4  2
# 2                274  60.97       1707+                54.48    7  11  1
# 3               270*  60.83        416+                56.00   10   5  2
# 4                194  60.73       6558+                34.59   16  23  2
#
#      4s  6s
# 0  626+   6
# 1   186   5
# 2  246+  11
# 3  104+   1
# 4  202+   6

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Player                 0
# Span                   0
# Matches                0
# Inns                   0
# Not_Outs               0
# Runs                   0
# Highest_Inns_Score     0
# Ave                    0
# Balls_Faced            4
# Batting_Strike_Rate    1
# 100                    0
# 50                     0
# 0                      0
# 4s                     0
# 6s                     0
# dtype: int64

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 7         ED Weekes (WI)  1948-1958       48    81         5  4455
# 16       CL Walcott (WI)  1948-1960       44    74         7  3798
# 56  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
# 57  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 7                 207  58.61         NaN                  NaN   15  19  6
# 16                220  56.68         NaN                  0.0   15  14  1
# 56               144*  48.79         NaN                  0.0    5   6  3
# 57               144*  48.79         NaN                  0.0    5   6  3
#
#       4s  6s
# 7   258+   2
# 16  107+  11
# 56   51+   0
# 57   51+   0

# %%
df[df['Batting_Strike_Rate'].isna()==1]
# Out:
#            Player       Span  Matches  Inns  Not_Outs  Runs  \
# 7  ED Weekes (WI)  1948-1958       48    81         5  4455
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 7                207  58.61         NaN                  NaN   15  19  6
#
#      4s 6s
# 7  258+  2

# %%
df['Balls_Faced']=df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate']=df['Batting_Strike_Rate'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Player                 0
# Span                   0
# Matches                0
# Inns                   0
# Not_Outs               0
# Runs                   0
# Highest_Inns_Score     0
# Ave                    0
# Balls_Faced            0
# Batting_Strike_Rate    0
# 100                    0
# 50                     0
# 0                      0
# 4s                     0
# 6s                     0
# dtype: int64

# %%
df[df['Player']=='ED Weekes (WI)']
# Out:
#            Player       Span  Matches  Inns  Not_Outs  Runs  \
# 7  ED Weekes (WI)  1948-1958       48    81         5  4455
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 7                207  58.61           0                  0.0   15  19  6
#
#      4s 6s
# 7  258+  2

# %%
df=df.drop_duplicates()

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# Length: 62, dtype: bool

# %%
df.head()
# Out:
#               Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0   DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1     AC Voges (AUS)  2015-2016       20    31         7  1485
# 2    RG Pollock (SA)  1963-1970       23    41         4  2256
# 3    GA Headley (WI)  1930-1954       22    40         4  2190
# 4  H Sutcliffe (ENG)  1924-1935       54    84         9  4555
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 0                334  99.94       9800+                58.60   29  13  7
# 1               269*  61.87        2667                55.68    5   4  2
# 2                274  60.97       1707+                54.48    7  11  1
# 3               270*  60.83        416+                56.00   10   5  2
# 4                194  60.73       6558+                34.59   16  23  2
#
#      4s  6s
# 0  626+   6
# 1   186   5
# 2  246+  11
# 3  104+   1
# 4  202+   6

# %%
df.dtypes['Span']
# Out:
# dtype('O')

# %%
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 4     [1924, 1935]
#           ...
# 60    [1965, 1981]
# 61    [2002, 2014]
# 62    [1924, 1934]
# 63    [1930, 1938]
# 64    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_Year']=df['Span'].str.split(pat= '-').str[0]

# %%
df['Final_Year']=df['Span'].str.split(pat= '-').str[1]

# %%
df.drop(['Span'], axis=1,inplace=True)

# %%
df.head()
# Out:
#               Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1     AC Voges (AUS)       20    31         7  1485               269*  61.87
# 2    RG Pollock (SA)       23    41         4  2256                274  60.97
# 3    GA Headley (WI)       22    40         4  2190               270*  60.83
# 4  H Sutcliffe (ENG)       54    84         9  4555                194  60.73
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        2667                55.68    5   4  2   186   5        2015
# 2       1707+                54.48    7  11  1  246+  11        1963
# 3        416+                56.00   10   5  2  104+   1        1930
# 4       6558+                34.59   16  23  2  202+   6        1924
#
#   Final_Year
# 0       1948
# 1       2016
# 2       1970
# 3       1954
# ...

# %%
df.isnull().sum()
# Out:
# Player                 0
# Matches                0
# Inns                   0
# Not_Outs               0
# Runs                   0
# Highest_Inns_Score     0
# Ave                    0
# Balls_Faced            0
# Batting_Strike_Rate    0
# 100                    0
# 50                     0
# 0                      0
# 4s                     0
# 6s                     0
# Rookie_Year            0
# Final_Year             0
# dtype: int64

# %%
df['Country']=df['Player'].str.split(pat= '(').str[1]

# %%
df['Country']
# Out:
# 0        AUS)
# 1        AUS)
# 2         SA)
# 3         WI)
# 4        ENG)
#        ...
# 60       AUS)
# 61    ICC/SA)
# 62       AUS)
# 63       AUS)
# 64       ENG)
# Name: Country, Length: 62, dtype: object

# %%
df['Player']=df['Player'].str.split(pat= '(').str[0]

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                334  99.94
# 1      AC Voges        20    31         7  1485               269*  61.87
# 2    RG Pollock        23    41         4  2256                274  60.97
# 3    GA Headley        22    40         4  2190               270*  60.83
# 4   H Sutcliffe        54    84         9  4555                194  60.73
# ..           ...      ...   ...       ...   ...                ...    ...
# 60   KD Walters        74   125        14  5357                250  48.26
# 61     GC Smith       117   205        13  9265                277  48.25
# 62  WH Ponsford        29    48         4  2122                266  48.22
# 63    SJ McCabe        39    62         5  2748                232  48.21
# 64   DR Jardine        22    33         6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
df['Country']=df['Country'].str.replace(')','',regex=False)

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                334  99.94
# 1      AC Voges        20    31         7  1485               269*  61.87
# 2    RG Pollock        23    41         4  2256                274  60.97
# 3    GA Headley        22    40         4  2190               270*  60.83
# 4   H Sutcliffe        54    84         9  4555                194  60.73
# ..           ...      ...   ...       ...   ...                ...    ...
# 60   KD Walters        74   125        14  5357                250  48.26
# 61     GC Smith       117   205        13  9265                277  48.25
# 62  WH Ponsford        29    48         4  2122                266  48.22
# 63    SJ McCabe        39    62         5  2748                232  48.21
# 64   DR Jardine        22    33         6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
df['Highest_Inns_Score']=df['Highest_Inns_Score'].str.replace('*','')

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman        52    80        10  6996                334  99.94
# 1     AC Voges        20    31         7  1485                269  61.87
# 2   RG Pollock        23    41         4  2256                274  60.97
# 3   GA Headley        22    40         4  2190                270  60.83
# 4  H Sutcliffe        54    84         9  4555                194  60.73
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        2667                55.68    5   4  2   186   5        2015
# 2       1707+                54.48    7  11  1  246+  11        1963
# 3        416+                56.00   10   5  2  104+   1        1930
# 4       6558+                34.59   16  23  2  202+   6        1924
#
#   Final_Year Country
# 0       1948     AUS
# 1       2016     AUS
# 2       1970      SA
# ...

# %%
df['Highest_Inns_Score']=df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df.rename(columns={'Ave':'Average'},inplace=True)

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score  Average  \
# 0   DG Bradman        52    80        10  6996                 334    99.94
# 1     AC Voges        20    31         7  1485                 269    61.87
# 2   RG Pollock        23    41         4  2256                 274    60.97
# 3   GA Headley        22    40         4  2190                 270    60.83
# 4  H Sutcliffe        54    84         9  4555                 194    60.73
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        2667                55.68    5   4  2   186   5        2015
# 2       1707+                54.48    7  11  1  246+  11        1963
# 3        416+                56.00   10   5  2  104+   1        1930
# 4       6558+                34.59   16  23  2  202+   6        1924
#
#   Final_Year Country
# 0       1948     AUS
# 1       2016     AUS
# 2       1970      SA
# ...

# %%
df['Rookie_Year']=df['Rookie_Year'].astype('int')

# %%
df['Final_Year']=df['Final_Year'].astype('int')

# %%
df['Matches']=df['Matches'].astype('int')

# %%
df['Batting_Strike_Rate']=df['Batting_Strike_Rate'].astype('float')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Average                float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['Balls_Faced']=df['Balls_Faced'].str.replace('+','')

# %%
df['Balls_Faced']
# Out:
# 0      9800
# 1      2667
# 2      1707
# 3       416
# 4      6558
#       ...
# 60     8662
# 61    15525
# 62     3118
# 63     3217
# 64     2110
# Name: Balls_Faced, Length: 62, dtype: object

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Average                False
# Balls_Faced             True
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#              Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score  \
# 7        ED Weekes        48    81         5  4455                 207
# 16      CL Walcott        44    74         7  3798                 220
# 56  Hon.FS Jackson        20    33         4  1415                 144
#
#     Average Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s  \
# 7     58.61         NaN                  0.0   15  19  6  258+   2
# 16    56.68         NaN                  0.0   15  14  1  107+  11
# 56    48.79         NaN                  0.0    5   6  3   51+   0
#
#     Rookie_Year  Final_Year Country
# 7          1948        1958      WI
# 16         1948        1960      WI
# 56         1893        1905     ENG

# %%
df['Balls_Faced']=df['Balls_Faced'].fillna(0)

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Average, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Country]
# Index: []

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Average                False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score  Average  \
# 0   DG Bradman        52    80        10  6996                 334    99.94
# 1     AC Voges        20    31         7  1485                 269    61.87
# 2   RG Pollock        23    41         4  2256                 274    60.97
# 3   GA Headley        22    40         4  2190                 270    60.83
# 4  H Sutcliffe        54    84         9  4555                 194    60.73
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s  Rookie_Year  \
# 0        9800                58.60   29  13  7  626+   6         1928
# 1        2667                55.68    5   4  2   186   5         2015
# 2        1707                54.48    7  11  1  246+  11         1963
# 3         416                56.00   10   5  2  104+   1         1930
# 4        6558                34.59   16  23  2  202+   6         1924
#
#    Final_Year Country
# 0        1948     AUS
# 1        2016     AUS
# ...

# %%
df['Balls_Faced']=df['Balls_Faced'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Average                float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['4s']=df['4s'].str.replace('+','')

# %%
df['4s']=df['4s'].astype('int')

# %%
df['6s']=df['6s'].str.replace('+','')

# %%
df['6s']=df['6s'].astype('int')

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score  Average  \
# 0   DG Bradman        52    80        10  6996                 334    99.94
# 1     AC Voges        20    31         7  1485                 269    61.87
# 2   RG Pollock        23    41         4  2256                 274    60.97
# 3   GA Headley        22    40         4  2190                 270    60.83
# 4  H Sutcliffe        54    84         9  4555                 194    60.73
#
#    Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0         9800                58.60   29  13  7  626   6         1928
# 1         2667                55.68    5   4  2  186   5         2015
# 2         1707                54.48    7  11  1  246  11         1963
# 3          416                56.00   10   5  2  104   1         1930
# 4         6558                34.59   16  23  2  202   6         1924
#
#    Final_Year Country
# 0        1948     AUS
# 1        2016     AUS
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Average                float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score  Average  \
# 0   DG Bradman        52    80        10  6996                 334    99.94
# 1     AC Voges        20    31         7  1485                 269    61.87
# 2   RG Pollock        23    41         4  2256                 274    60.97
# 3   GA Headley        22    40         4  2190                 270    60.83
# 4  H Sutcliffe        54    84         9  4555                 194    60.73
#
#    Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0         9800                58.60   29  13  7  626   6         1928
# 1         2667                55.68    5   4  2  186   5         2015
# 2         1707                54.48    7  11  1  246  11         1963
# 3          416                56.00   10   5  2  104   1         1930
# 4         6558                34.59   16  23  2  202   6         1924
#
#    Final_Year Country
# 0        1948     AUS
# 1        2016     AUS
# ...

# %%
df['Career_Length']=df['Final_Year']-df['Rookie_Year']

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score  Average  \
# 0   DG Bradman        52    80        10  6996                 334    99.94
# 1     AC Voges        20    31         7  1485                 269    61.87
# 2   RG Pollock        23    41         4  2256                 274    60.97
# 3   GA Headley        22    40         4  2190                 270    60.83
# 4  H Sutcliffe        54    84         9  4555                 194    60.73
#
#    Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0         9800                58.60   29  13  7  626   6         1928
# 1         2667                55.68    5   4  2  186   5         2015
# 2         1707                54.48    7  11  1  246  11         1963
# 3          416                56.00   10   5  2  104   1         1930
# 4         6558                34.59   16  23  2  202   6         1924
#
#    Final_Year Country  Career_Length
# 0        1948     AUS             20
# ...

# %%
mean=df['Career_Length'].mean()

# %%
print('Average Career Length of Cricket Players:',mean)
# Out:
# Average Career Length of Cricket Players: 12.96774193548387

# %%
df['Batting_Strike_Rate'].mean()
# Out:
# np.float64(47.58435483870967)

# %%
pros=df[df['Career_Length']>10]

# %%
mean2=pros['Batting_Strike_Rate'].mean()

# %%
print('Average Batting Strike of Cricket Players over 10 Years:',mean2)
# Out:
# Average Batting Strike of Cricket Players over 10 Years: 47.785348837209305

# %%
count=df[df['Rookie_Year']<1960]['Player'].count()

# %%
print('Number of Cricketers who played before 1960:',count)
# Out:
# Number of Cricketers who played before 1960: 23

# %% [markdown]
# # Performed Data Cleaning by removing null values,removing duplicates,renaming columns and performed some statistics
